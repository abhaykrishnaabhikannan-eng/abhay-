# %%
# #Task 1
# Read the Population dataset from the CSV file
import pandas as pd
population = pd.read_csv('population.csv')
population.head()
# Out:
#          country  population
# 0  United States   331002651
# 1          China  1411778724
# 2          India  1380004385
# 3          Japan   125836021
# 4        Germany    83240525

# %%
population.shape
# Out:
# (25, 2)

# %%
population.dtypes
# Out:
# country       object
# population     int64
# dtype: object

# %%
# Task 2
# Read the GDP dataset from the Excel file.

gdp = pd.read_excel("gdp.xlsx")
gdp.head()
# Out:
#          Country       GDP
# 0  United States  30500000
# 1          China  19230000
# 2          India   4187000
# 3          Japan   4180000
# 4        Germany   4744000

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  25 non-null     object
#  1   GDP      25 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 532.0+ bytes

# %%
gdp.dtypes
# Out:
# Country    object
# GDP         int64
# dtype: object

# %%
# Task 3
# Read the Internet Users dataset from the JSON file.
internet_users = pd.read_json('internet_users.json')
internet_users
# Out:
#            country  internet_users
# 0    United States       312000000
# 1            China      1080000000
# 2            India       850000000
# 3            Japan       118000000
# 4          Germany        79000000
# 5   United Kingdom        66000000
# 6           France        62000000
# 7            Italy        56000000
# 8           Canada        36000000
# 9        Australia        24000000
# 10          Brazil       181000000
# 11          Russia       125000000
# 12     South Korea        50000000
# 13           Spain        44000000
# 14          Mexico       102000000
# 15       Indonesia       212000000
# 16    Saudi Arabia        34000000
# 17          Turkey        69000000
# 18    South Africa        43000000
# 19       Argentina        41000000
# 20     Netherlands        17000000
# 21     Switzerland         8500000
# 22          Sweden        10100000
# 23          Norway         5300000
# 24       Singapore         5600000

# %%
internet_users = pd.DataFrame(internet_users)
internet_users
# Out:
#            country  internet_users
# 0    United States       312000000
# 1            China      1080000000
# 2            India       850000000
# 3            Japan       118000000
# 4          Germany        79000000
# 5   United Kingdom        66000000
# 6           France        62000000
# 7            Italy        56000000
# 8           Canada        36000000
# 9        Australia        24000000
# 10          Brazil       181000000
# 11          Russia       125000000
# 12     South Korea        50000000
# 13           Spain        44000000
# 14          Mexico       102000000
# 15       Indonesia       212000000
# 16    Saudi Arabia        34000000
# 17          Turkey        69000000
# 18    South Africa        43000000
# 19       Argentina        41000000
# 20     Netherlands        17000000
# 21     Switzerland         8500000
# 22          Sweden        10100000
# 23          Norway         5300000
# 24       Singapore         5600000

# %%
# Task 4
# Read the Literacy Rate dataset from the XML file

literacy_rate = pd.read_xml('literacy_rate.xml')
literacy_rate
# Out:
#               name  literacy_rate
# 0    United States           99.0
# 1            China           97.2
# 2            India           77.7
# 3            Japan           99.0
# 4          Germany           99.0
# 5   United Kingdom           99.0
# 6           France           99.0
# 7            Italy           99.0
# 8           Canada           99.0
# 9        Australia           99.0
# 10          Brazil           93.2
# 11          Russia           99.7
# 12     South Korea           98.8
# 13           Spain           98.6
# 14          Mexico           95.4
# 15       Indonesia           96.0
# 16    Saudi Arabia           97.3
# 17          Turkey           96.7
# 18    South Africa           95.0
# 19       Argentina           99.1
# 20     Netherlands           99.0
# 21     Switzerland           99.0
# 22          Sweden           99.0
# 23          Norway          100.0
# 24       Singapore           97.5

# %%
# Task 5
# Number of rows
# ● Number of columns
# ● Column names
# ● Data types
# ● Missing values
# ● Duplicate records

# %%
#population data set
population.info()
population.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     25 non-null     object
#  1   population  25 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 532.0+ bytes
# np.int64(0)

# %%
#gdp data set
gdp.info()
gdp.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  25 non-null     object
#  1   GDP      25 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 532.0+ bytes
# np.int64(0)

# %%
#internet user data set

internet_users.info()
internet_users.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         25 non-null     object
#  1   internet_users  25 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 532.0+ bytes
# np.int64(0)

# %%
# literacy rate data set

literacy_rate.info()
literacy_rate.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        25 non-null     object
#  1   literacy_rate  25 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 532.0+ bytes
# np.int64(0)

# %%
# Task 6

gdp = gdp.rename(columns={'Country': 'country'})
literacy_rate = literacy_rate.rename(columns={'name': 'country'})
# Out:
# ['country', 'population']
# ['country', 'GDP']
# ['country', 'internet_users']
# ['country', 'literacy_rate']

# %% [markdown]
# # Task 7 - Convert the required columns into appropriate numeric data types.
#
# given data set already numeric

# %%
# Task 8
# Merge all four datasets into one DataFrame


merged_df = population.merge(gdp, on='country', how='inner')
merged_df = merged_df.merge(internet_users, on='country', how='inner')
merged_df = merged_df.merge(literacy_rate, on='country', how='inner')

merged_df.head()
# Out:
#          country  population       GDP  internet_users  literacy_rate
# 0  United States   331002651  30500000       312000000           99.0
# 1          China  1411778724  19230000      1080000000           97.2
# 2          India  1380004385   4187000       850000000           77.7
# 3          Japan   125836021   4180000       118000000           99.0
# 4        Germany    83240525   4744000        79000000           99.0

# %%
# Task 9
# Create the following calculated columns:

merged_df['Internet Penetration (%)'] = (merged_df['internet_users'] / merged_df['population']) * 100
merged_df['GDP Per Capita'] = merged_df['GDP'] / merged_df['population']

merged_df.head()
# Out:
#          country  population       GDP  internet_users  literacy_rate  \
# 0  United States   331002651  30500000       312000000           99.0
# 1          China  1411778724  19230000      1080000000           97.2
# 2          India  1380004385   4187000       850000000           77.7
# 3          Japan   125836021   4180000       118000000           99.0
# 4        Germany    83240525   4744000        79000000           99.0
#
#    Internet Penetration (%)  GDP Per Capita
# 0                 94.259064        0.092144
# 1                 76.499240        0.013621
# 2                 61.594007        0.003034
# 3                 93.772832        0.033218
# 4                 94.905696        0.056991

# %%
# Task 10

import sqlite3

conn = sqlite3.connect('country_statistics.db')
merged_df.to_sql('country_statistics', conn)
# Out:
# 25

# %%
# Task 11

q = "SELECT * FROM country_statistics LIMIT 5"
db = pd.read_sql_query(q, conn)

db
# Out:
#    index        country  population       GDP  internet_users  literacy_rate  \
# 0      0  United States   331002651  30500000       312000000           99.0
# 1      1          China  1411778724  19230000      1080000000           97.2
# 2      2          India  1380004385   4187000       850000000           77.7
# 3      3          Japan   125836021   4180000       118000000           99.0
# 4      4        Germany    83240525   4744000        79000000           99.0
#
#    Internet Penetration (%)  GDP Per Capita
# 0                 94.259064        0.092144
# 1                 76.499240        0.013621
# 2                 61.594007        0.003034
# 3                 93.772832        0.033218
# 4                 94.905696        0.056991

# %%
# Part E – Data Analysis Using Pandas

# %%
# 1. Top 5 countries by GDP

merged_df.nlargest(5, 'GDP')[['country', 'GDP']]
# Out:
#          country       GDP
# 0  United States  30500000
# 1          China  19230000
# 4        Germany   4744000
# 2          India   4187000
# 3          Japan   4180000

# %%
# 2. List the Top 5 countries by population.
merged_df.nlargest(5, 'population')[['country', 'population']]
# Out:
#           country  population
# 1           China  1411778724
# 2           India  1380004385
# 0   United States   331002651
# 15      Indonesia   273523615
# 10         Brazil   212559417

# %%
# 3. Average literacy rate
merged_df['literacy_rate'].mean()
# Out:
# np.float64(97.248)

# %%
# 4. Countries with literacy rate greater than 90%:
merged_df[merged_df['literacy_rate'] > 90][['country', 'literacy_rate']]
# Out:
#            country  literacy_rate
# 0    United States           99.0
# 1            China           97.2
# 3            Japan           99.0
# 4          Germany           99.0
# 5   United Kingdom           99.0
# 6           France           99.0
# 7            Italy           99.0
# 8           Canada           99.0
# 9        Australia           99.0
# 10          Brazil           93.2
# 11          Russia           99.7
# 12     South Korea           98.8
# 13           Spain           98.6
# 14          Mexico           95.4
# 15       Indonesia           96.0
# 16    Saudi Arabia           97.3
# 17          Turkey           96.7
# 18    South Africa           95.0
# 19       Argentina           99.1
# 20     Netherlands           99.0
# 21     Switzerland           99.0
# 22          Sweden           99.0
# 23          Norway          100.0
# 24       Singapore           97.5

# %%
# 5. Countries with internet penetration greater than 70%

merged_df[merged_df['Internet Penetration (%)'] > 70][['country', 'Internet Penetration (%)']]
# Out:
#            country  Internet Penetration (%)
# 0    United States                 94.259064
# 1            China                 76.499240
# 3            Japan                 93.772832
# 4          Germany                 94.905696
# 5   United Kingdom                 97.221797
# 6           France                 94.984932
# 7            Italy                 92.620425
# 8           Canada                 94.723785
# 9        Australia                 93.432326
# 10          Brazil                 85.152661
# 11          Russia                 85.654888
# 12     South Korea                 96.561300
# 13           Spain                 94.108029
# 14          Mexico                 79.111008
# 15       Indonesia                 77.507019
# 16    Saudi Arabia                 97.662222
# 17          Turkey                 81.812620
# 18    South Africa                 72.502023
# 19       Argentina                 90.716446
# 20     Netherlands                 97.470698
# ...

# %%
# 6. Top 5 countries by GDP per capita
merged_df.nlargest(5, 'GDP Per Capita')[['country', 'GDP Per Capita']]
# Out:
#           country  GDP Per Capita
# 21    Switzerland        0.108612
# 23         Norway        0.106987
# 0   United States        0.092144
# 24      Singapore        0.090593
# 9       Australia        0.073189

# %%
# 7. Total population represented in the dataset

merged_df['population'].sum()
# Out:
# np.int64(4720039725)

# %%
# 8. Average internet penetration across all countries

merged_df['Internet Penetration (%)'].mean()
# Out:
# np.float64(89.6609210897238)

# %%
# 9. Country having the highest number of internet users

merged_df.loc[merged_df['internet_users'].idxmax()][['country', 'internet_users']]
# Out:
# country                China
# internet_users    1080000000
# Name: 1, dtype: object

# %%
# 10. Correlation between Literacy Rate and Internet Penetration

merged_df['literacy_rate'].corr(merged_df['Internet Penetration (%)'])
# Out:
# np.float64(0.7727536531179539)

# %%
# Part F – Data Analysis Using SQL

# %%
# 11. Display the Top 5 countries by GDP:
q = "SELECT country, GDP FROM country_statistics ORDER BY GDP DESC LIMIT 5"
df= pd.read_sql_query(q, conn)
df
# Out:
#          country       GDP
# 0  United States  30500000
# 1          China  19230000
# 2        Germany   4744000
# 3          India   4187000
# 4          Japan   4180000

# %%
# 12. Find the average literacy rate:
q = "SELECT AVG(literacy_rate) FROM country_statistics"
df = pd.read_sql_query(q, conn)
df
# Out:
#    AVG(literacy_rate)
# 0              97.248

# %%
# 13. Display all countries having literacy rate above 90%:
q = '''SELECT country, literacy_rate
FROM country_statistics
WHERE literacy_rate > 90
ORDER BY literacy_rate DESC '''
df = pd.read_sql_query(q, conn)
df
# Out:
#            country  literacy_rate
# 0           Norway          100.0
# 1           Russia           99.7
# 2        Argentina           99.1
# 3    United States           99.0
# 4            Japan           99.0
# 5          Germany           99.0
# 6   United Kingdom           99.0
# 7           France           99.0
# 8            Italy           99.0
# 9           Canada           99.0
# 10       Australia           99.0
# 11     Netherlands           99.0
# 12     Switzerland           99.0
# 13          Sweden           99.0
# 14     South Korea           98.8
# 15           Spain           98.6
# 16       Singapore           97.5
# 17    Saudi Arabia           97.3
# 18           China           97.2
# 19          Turkey           96.7
# 20       Indonesia           96.0
# 21          Mexico           95.4
# 22    South Africa           95.0
# 23          Brazil           93.2

# %%
# 14. Find the Top 5 countries with the highest internet penetration:

q = ''' SELECT country, \"Internet Penetration (%)\"
FROM country_statistics
ORDER BY \"Internet Penetration (%)\" DESC LIMIT 5 '''
df = pd.read_sql_query(q, conn)
df
# Out:
#         country  Internet Penetration (%)
# 0   Switzerland                 98.213417
# 1        Norway                 97.763593
# 2  Saudi Arabia                 97.662222
# 3        Sweden                 97.552099
# 4   Netherlands                 97.470698

# %%
# 15. Calculate the total population

q = '''SELECT SUM(population)
FROM country_statistics'''
df = pd.read_sql_query(q, conn)
df
# Out:
#    SUM(population)
# 0       4720039725

# %%
# 16. Find the country with the highest GDP per capita:
q = '''SELECT country, \"GDP Per Capita\"
FROM country_statistics
ORDER BY \"GDP Per Capita\" DESC LIMIT 1 '''
df =pd.read_sql_query(q, conn)
df
# Out:
#        country  GDP Per Capita
# 0  Switzerland        0.108612

# %%
# 17. Export the final merged dataset as a CSV file.


df = pd.read_sql_query("SELECT * FROM country_statistics", conn)
df.to_csv('country_statistics.csv', index=False)

# %%
# 18. Sort the dataset in descending order of GDP per Capita and display the Top 10 countries
query= '''SELECT country, \"GDP Per Capita\"
FROM country_statistics
ORDER BY \"GDP Per Capita\" DESC LIMIT 10'''
df = pd.read_sql_query(q, conn)
df
# Out:
#        country  GDP Per Capita
# 0  Switzerland        0.108612
